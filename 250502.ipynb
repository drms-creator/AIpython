# %% [markdown]
# <a href="https://colab.research.google.com/github/drms-creator/AIpython/blob/main/250502.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **08장 연습문제**

# %% [markdown]
# 1번

# %%
import matplotlib.pyplot as plt

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
temperatures = [5, 7, 12, 18, 22]

# %%
plt.plot(months, temperatures)

# %%
plt.plot(months, temperatures)
plt.title('Monthly Temperature Change')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show() # show는 인자를 아무것도 안받음

# %%
plt.plot(months, temperatures)
plt.title('월별 온도 변화')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show() # show는 인자를 아무것도 안받음

# 한글 설정이 필요함
# 웬만하면 영문 작성으로 (기본)
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
months
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May']

# %%
temperatures
# Out:
# [5, 7, 12, 18, 22]

# %%
import seaborn as sns

# %%
# 예시 데이터: 키와 몸무게
height = [160, 165, 170, 175, 180]
weight = [55, 60, 68, 72, 78]

plt.scatter(height, weight) # x축 데이터, y축 데이터
plt.title('Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
# 예시 데이터: 과일별 판매량
fruits = ['Apple', 'Banana', 'Orange']
sales = [100, 150, 80]

plt.bar(fruits, sales) # x축 카테고리, y축 값
plt.title('Fruit Sales')
plt.xlabel('Fruit')
plt.ylabel('Quantity Sold')
plt.show()

# %%
# 예시 데이터: 학생들의 시험 점수 # 빈도 수
scores = [65, 72, 75, 78, 80, 82, 85, 88, 90, 91, 93, 95, 98, 100]

plt.hist(scores, bins=5) # 데이터, 구간(bin) 개수 설정
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
# 예시 데이터: 학생들의 시험 점수
scores = [65, 72, 75, 78, 80, 82, 85, 88, 90, 91, 93, 95, 98, 100]

plt.hist(scores, bins=6) # 데이터, 구간(bin) 개수 설정
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum # yes 자동 대답이라는 뜻
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,265 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !sudo apt-get install -y fonts-Gulim # yes 자동 대답이라는 뜻
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package fonts-Gulim

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt



# Mac의 한글폰트 설정
plt.rc("font", family = "AppleGothic")

# 음수기호(-) 제대로 표기하기 위한 코드
plt.rc("axes", unicode_minus = False)

# 폰트 선명하게 보이도록
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")
# Out:
# <ipython-input-67-2cc2f873b93f>:13: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats("retina")

# %%
plt.rc('font', family='AppleGothic')
plt.plot(months, temperatures)
plt.title('월별 온도 변화')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show() # show는 인자를 아무것도 안받음

# %%
import os
import matplotlib.font_manager as fm

# 시스템에 설치된 모든 TTF 폰트 목록 출력
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
print(len(font_list))
print(font_list[:5])  # 처음 5개만 출력

# 폰트 이름으로 확인하기
font_names = [fm.FontProperties(fname=font).get_name() for font in font_list[:10]]
print(font_names)

# 한글 폰트 찾기 (예: 'Gothic', 'Myungjo', 'Batang', '고딕', '명조' 등 포함된 이름)
korean_fonts = [font for font in font_list if any(x in os.path.basename(font).lower() for x in ['gothic', 'myungjo', 'batang', '고딕', '명조', 'apple', 'nanum'])]
print(korean_fonts)
# Out:
# 29
# ['/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf', '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf', '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf', '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf', '/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf']
# ['Liberation Sans', 'NanumSquare', 'NanumBarunGothic', 'Liberation Sans Narrow', 'Liberation Mono', 'Liberation Serif', 'Liberation Serif', 'NanumBarunGothic', 'Liberation Sans Narrow', 'NanumGothic']
# ['/usr/share/fonts/truetype/nanum/NanumSquareB.ttf', '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf', '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', '/usr/share/fonts/truetype/nanum/NanumGothic.ttf', '/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf', '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf', '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf', '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf', '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf', '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf', '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf', '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf']

# %%
import warnings
import logging

logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
#선그래프
#그래프 출력

# %%
plt.plot(year,kor)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
plt.bar(year,kor)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
plt.hist(year)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
import matplotlib.pyplot as plt

year = ['2006', '2009', '2012', '2015', '2018']
kor = [547, 546, 554, 524, 526]
#막대그래프
plt.bar(year,kor)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
import matplotlib.pyplot as plt

kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
#산점도그래프
plt.scatter(kor,usa)
plt.show()

# %%
import matplotlib.pyplot as plt

score = [547,546,554,524,526,474,487,481,470,478,523,529,536,532,527]
#히스토그램
plt.hist(score)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2009, 2012, 2015]
y = [529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2006, 2009, 2012, 2015]
y = [523, 529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['a', 'b', 'c']
y = [7, 5, 4]
plt.xlabel("x")
plt.ylabel("y")
plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
plt.plot(year, kor)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
# year kor 그래프
# year usa 그래프

# %%
# year kor 그래프
plt.plot(year, kor)
plt.xlabel("year")
plt.ylabel("kor")
plt.show()

# %%
# year usa 그래프
plt.plot(year,usa)
plt.xlabel("year")
plt.ylabel("usa")
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
jpn = [523, 529, 536, 532, 527]

# 그래프가 가로와 세로 크기를 각각 5인치와 3인치 크기 설정
# year 데이터를 x축으로, kor 데이터를 y축으로 하여 빨간색 점선으로 선 그래프를 그리고 범례에 'Korea'라고 표시
plt.plot(year, usa, 'b:', ) #범례에 'Korea'라고 표시
plt.plot(year, jpn, 'g-', label='Japan')
plt.ylim(400, 600)  # y축 범위 설정
# 그래프에 범례를 추가
# 그래프 제목을 'Mathematics performance'로 설정합니다.
plt.xlabel('year')
plt.ylabel('score')
plt.show()

# %%
import matplotlib.pyplot as plt

notebook = {'g○○':150,'t○○':100,'m○○':160,'s○○':170}

plt.figure(figsize=(5,3))
# 막대 그래프의 x축은 딕셔너리의 키(제품이름)를 사용하고, 막대 그래프의 Y축은 딕셔너리의 값(가격)을 사용하고, 각 막대의 너비를 0.7 단위로 설정
plt.xlabel('product name')
plt.ylabel('price')
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2000, 2005, 2010, 2015, 2020]
single_person = [15.5, 20.0, 23.9, 27.2, 31.7]
baby_born = [640089, 438707, 470171, 438420, 272337]

plt.figure(figsize=(5,3))
 # 1인 가구 비율(single_person)과 출생아 수(baby_born) 사이의 관계를 나타내는 산점도를 그립니다.
for i in range(len(year)):
  plt.annotate(year[i],xy=(single_person[i], baby_born[i]),xytext=(5,-10),textcoords='offset points') #각 연도에 해당하는 데이터 지점 옆에 해당 연도를 표시하는 주석을 추가
plt.xlim(14,35)
plt.ylim(230000,700000)
plt.xlabel('single-person household ratio')
plt.ylabel('the number of babies born')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x = [random.randint(1,100) for i in range(1000)]

plt.figure(figsize=(5,3))
# 데이터 배열 x를 20개의 구간으로 나누고 50% 투명도로 표시하는 빈도 분포 그래프를 생성
plt.ylabel('frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

exercise ={'climbing':0,'soccer':0,'swimming':0,'tennis':0}

print('좋아하는 운동을 입력하세요.')
print('복수 개의 운동을 입력하려면 콤마로 구분하세요.')

while True:
  s = input('climbing,soccer,swimming,tennis,종료: ')
  if s=='종료':
    break
  for a in s.split(','):
    if a in exercise:
      # 해당 운동의 카운트를 1 증가시키는 연산
    else:
      print(f'{a}는 등록되지 않은 운동입니다.')

plt.figure(figsize=(5.5,3))
plt.bar(exercise.keys(), exercise.values(), color='g', width=0.6)
#plt.xticks(rotation='vertical')
plt.xlabel('exercise')
plt.ylabel('frequency')
plt.show()

# %%
Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]
plt.plot(Month, Rainfall)
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.show()

# %%
import matplotlib.pyplot as plt

# 먼저 figure 생성 (figure은 무조건 plot 전에 해야함!!)
plt.figure(figsize=(12, 10))

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall)
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("<Monthly Rainfall>")
plt.show()

# %%
import matplotlib.pyplot as plt

# 먼저 figure 생성
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall)
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'r')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
# RGB 색상 코드

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'b', linestyle = '--')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
# '-' : 실선 -> 기본값
# '--' : 파선
# '-.' : 일점 쇄선
# ':' : 점선

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'g', linestyle = '-.')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'm', linestyle = ':')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'm', marker='o', linestyle = '-')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'm', marker='h', linestyle = ':') #hexa
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, color = 'm', marker = 'x', linestyle = ':')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
# 순서는 색상, 마크, 라인스타일 순서대로!

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, 'mx:')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0,400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.plot(Month, Rainfall, 'gx-')
plt.xlabel("Month")
plt.ylabel("Rainfall(mm)")
plt.title("Monthly Rainfall")
plt.show()

# %%
year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

# %%
plt.plot(year, seoul, 'gh-', label = 'seoul') # label : 범레명
plt.plot(year, jeju, 'bo-', label = 'jeju')
plt.xlabel('year')
plt.ylabel('temperature')
plt.legend()
plt.show()

# %%
preci = {'spring':330.5, 'summer':612.8, 'autumn':256.4, 'winter':13.3}
plt.bar(preci.keys(), preci.values())
plt.xlabel('season')
plt.ylabel('precipitation')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
plt.ylim(0, 400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.scatter(Month, Rainfall, s=100, color='blue')
plt.xlabel("Month", fontsize=14)
plt.ylabel("Rainfall(mm)", fontsize=14)
plt.title("Monthly Rainfall", fontsize=18)

# annotate를 사용하여 각 점 위에 강수량 표시
for i, txt in enumerate(Rainfall):
    plt.annotate(f"{txt}mm",
                 (Month[i], Rainfall[i]),
                 textcoords="offset points",
                 xytext=(0, 10),  # 텍스트를 점 위에 10 포인트 위치시킴
                 ha='center',     # 수평 정렬 중앙
                 fontsize=12)     # 글씨 크기 설정

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
plt.ylim(0, 400)

Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Rainfall = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]

# 그래프 그리기
plt.scatter(Month, Rainfall, s=100, color='blue')
plt.xlabel("Month", fontsize=14)
plt.ylabel("Rainfall(mm)", fontsize=14)
plt.title("Monthly Rainfall", fontsize=18)

# annotate를 사용하여 각 점 위에 강수량 표시
for i in range(len(Rainfall)):
    txt = str(Rainfall[i])
    plt.annotate(f"{txt}mm",
                 (Month[i], Rainfall[i]),
                 textcoords="offset points",
                 xytext=(0, 10),  # 텍스트를 점 위에 10 포인트 위치시킴
                 ha='center',     # 수평 정렬 중앙
                 fontsize=12)     # 글씨 크기 설정

plt.show()
